# %% [markdown]
# ## Question 1 Part 2

# %%
#importing all the required libraries
import pandas as pd
import csv
import datetime

df1=pd.read_csv('vehicle_collisions.csv')
df1.head()
# Out:
#    UNIQUE KEY    DATE  TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15  0:20    QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15  0:20       NaN       NaN  40.771289 -73.946693
# 2     3146384  1/1/15  0:21  BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15  0:30  BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15  0:33       NaN       NaN        NaN        NaN
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# 1  (40.7712888, -73.9466928)               NaN                 NaN
# 2  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# 3  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# 4                        NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#         ...                      VEHICLE 1 TYPE     VEHICLE 2 TYPE  \
# 0       ...         SPORT UTILITY/STATION WAGON                NaN
# 1       ...                   PASSENGER VEHICLE                NaN
# 2       ...                   PASSENGER VEHICLE            UNKNOWN
# 3       ...                                 BUS  PASSENGER VEHICLE
# 4       ...                             UNKNOWN  PASSENGER VEHICLE
#
#    VEHICLE 3 TYPE  VEHICLE 4 TYPE  VEHICLE 5 TYPE  \
# 0             NaN             NaN             NaN
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN
# 3             NaN             NaN             NaN
# 4             NaN             NaN             NaN
#
#               VEHICLE 1 FACTOR  VEHICLE 2 FACTOR  VEHICLE 3 FACTOR  \
# 0  TRAFFIC CONTROL DISREGARDED               NaN               NaN
# 1               ANIMALS ACTION               NaN               NaN
# 2              FATIGUED/DROWSY       UNSPECIFIED               NaN
# 3           LOST CONSCIOUSNESS               NaN               NaN
# 4                  UNSPECIFIED       UNSPECIFIED               NaN
#
#    VEHICLE 4 FACTOR VEHICLE 5 FACTOR
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
#
# [5 rows x 29 columns]

# %%
groupedByBorough=pd.DataFrame(df1.groupby(['BOROUGH']).size().reset_index())
groupedByBorough
# Out:
#          BOROUGH       0
# 0          BRONX   46124
# 1       BROOKLYN  104961
# 2      MANHATTAN   83602
# 3         QUEENS   89655
# 4  STATEN ISLAND   14048

# %%
groupedByBorough['One Vehicle Involved']=groupedByBorough['BOROUGH'].apply(lambda x: len(df1[(df1['BOROUGH']==x)
& (df1['VEHICLE 1 TYPE'].isnull()==False)& (df1['VEHICLE 2 TYPE'].isnull()==True) & (df1['VEHICLE 3 TYPE'].isnull()==True)
& (df1['VEHICLE 4 TYPE'].isnull()==True)& (df1['VEHICLE 5 TYPE'].isnull()==True)]))

# %%
groupedByBorough['Two Vehicles Involved']=groupedByBorough['BOROUGH'].apply(lambda x: len(df1[(df1['BOROUGH']==x)
& (df1['VEHICLE 1 TYPE'].isnull()==False) & (df1['VEHICLE 2 TYPE'].isnull()==True) & (df1['VEHICLE 3 TYPE'].isnull()==True)
 & (df1['VEHICLE 4 TYPE'].isnull()==True)   & (df1['VEHICLE 5 TYPE'].isnull()==True)]))

# %%
groupedByBorough['Three Vehicles Involved']=groupedByBorough['BOROUGH'].apply(lambda x: len(df1[(df1['BOROUGH']==x)
& (df1['VEHICLE 1 TYPE'].isnull()==False) & (df1['VEHICLE 2 TYPE'].isnull()==True) & (df1['VEHICLE 3 TYPE'].isnull()==True)
 & (df1['VEHICLE 4 TYPE'].isnull()==True)   & (df1['VEHICLE 5 TYPE'].isnull()==True)]))

# %%
groupedByBorough['Four Vehicles Involved']=groupedByBorough['BOROUGH'].apply(lambda x: len(df1[(df1['BOROUGH']==x)
& (df1['VEHICLE 1 TYPE'].isnull()==False) & (df1['VEHICLE 2 TYPE'].isnull()==True) & (df1['VEHICLE 3 TYPE'].isnull()==True)
 & (df1['VEHICLE 4 TYPE'].isnull()==True)   & (df1['VEHICLE 5 TYPE'].isnull()==True)]))

# %%
groupedByBorough['Five Vehicles Involved']=groupedByBorough['BOROUGH'].apply(lambda x: len(df1[(df1['BOROUGH']==x)
& (df1['VEHICLE 1 TYPE'].isnull()==False) & (df1['VEHICLE 2 TYPE'].isnull()==True) & (df1['VEHICLE 3 TYPE'].isnull()==True)
 & (df1['VEHICLE 4 TYPE'].isnull()==True)   & (df1['VEHICLE 5 TYPE'].isnull()==True)]))

# %%
groupedByBorough
# Out:
#          BOROUGH       0  One Vehicle Involved  Two Vehicles Involved  \
# 0          BRONX   46124                  8627                   8627
# 1       BROOKLYN  104961                 17375                  17375
# 2      MANHATTAN   83602                 13318                  13318
# 3         QUEENS   89655                 12962                  12962
# 4  STATEN ISLAND   14048                  2343                   2343
#
#    Three Vehicles Involved  Four Vehicles Involved  Five Vehicles Involved
# 0                     8627                    8627                    8627
# 1                    17375                   17375                   17375
# 2                    13318                   13318                   13318
# 3                    12962                   12962                   12962
# 4                     2343                    2343                    2343

# %%
groupedByBorough.to_csv(r'C:\Users\smrut\Documents\Python\PythonAssignment3\Assignment 3\Ques1Part2Result.csv', sep=',')
