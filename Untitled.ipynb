# %%
import pandas as pd
import csv
import datetime


df=pd.read_csv(r'C:\Users\smrut\Documents\Python\PythonAssignment3\Assignment 3\Data\vehicle_collisions.csv',parse_dates=['DATE'])

ts=pd.to_datetime('1/1/2016')
gt=df.loc[df.DATE >=ts, :]
per=dp[df.BOROUGH=='MANHATTAN']
per.head()

#f['DATE'] = pd.to_datetime(df['DATE']) 
#ask = (df['DATE'] > '1/1/2016') & (df['DATE'] <= '12/31/2016')
#print(df.loc[mask])
#ns=(df.groupby(df['DATE'] > '1/1/2016') & (df['DATE'] <= '12/31/2016')).BOROUGH=='MANHATTAN'
#s
# Out:
# C:\Users\smrut\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     UNIQUE KEY       DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 8      3145900 2015-01-01  10:06  MANHATTAN   10024.0  40.787223 -73.967926
# 10     3145881 2015-01-01  10:15  MANHATTAN   10036.0  40.762184 -73.993611
# 12     3146152 2015-01-01  10:30  MANHATTAN   10018.0  40.756489 -73.997759
# 17     3145897 2015-01-01  11:15  MANHATTAN   10065.0  40.760857 -73.961069
# 19     3147994 2015-01-01  11:24  MANHATTAN   10031.0  40.823120 -73.950497
#
#                      LOCATION   ON STREET NAME  CROSS STREET NAME  \
# 8   (40.7872228, -73.9679255)   WEST 89 STREET  CENTRAL PARK WEST
# 10  (40.7621841, -73.9936106)        10 AVENUE     WEST 46 STREET
# 12  (40.7564889, -73.9977585)        10 AVENUE     WEST 37 STREET
# 17  (40.7608574, -73.9610689)   EAST 61 STREET           1 AVENUE
# 19  (40.8231203, -73.9504966)  WEST 141 STREET     HAMILTON PLACE
#
#          ...            VEHICLE 1 TYPE     VEHICLE 2 TYPE  VEHICLE 3 TYPE  \
# 8        ...         PASSENGER VEHICLE                NaN             NaN
# 10       ...         PASSENGER VEHICLE  PASSENGER VEHICLE             NaN
# 12       ...                      TAXI  PASSENGER VEHICLE             NaN
# 17       ...         PASSENGER VEHICLE               TAXI             NaN
# 19       ...                       VAN            UNKNOWN             NaN
#
#     VEHICLE 4 TYPE  VEHICLE 5 TYPE                VEHICLE 1 FACTOR  \
# 8              NaN             NaN                     UNSPECIFIED
# 10             NaN             NaN                     UNSPECIFIED
# 12             NaN             NaN  DRIVER INATTENTION/DISTRACTION
# 17             NaN             NaN                 OTHER VEHICULAR
# 19             NaN             NaN                     UNSPECIFIED
#
#     VEHICLE 2 FACTOR  VEHICLE 3 FACTOR  VEHICLE 4 FACTOR VEHICLE 5 FACTOR
# 8                NaN               NaN               NaN              NaN
# 10       UNSPECIFIED               NaN               NaN              NaN
# 12   OTHER VEHICULAR               NaN               NaN              NaN
# 17   OTHER VEHICULAR               NaN               NaN              NaN
# 19       UNSPECIFIED               NaN               NaN              NaN
#
# [5 rows x 29 columns]

# %%
import pandas as pd
import csv
import datetime

df=pd.read_csv(r'C:\Users\smrut\Documents\Python\PythonAssignment3\Assignment 3\Data\vehicle_collisions.csv',parse_dates=['DATE'])
aim=df[df.BOROUGH=='MANHATTAN'] 
df['DATE'] = pd.to_datetime(df['DATE']) 
mask = (df['DATE'] > '1/1/2016') & (df['DATE'] <= '12/31/2016')
#print(df.loc[mask])
ans=(df.groupby(df['DATE'] > '1/1/2016') & (df['DATE'] <= '12/31/2016')).BOROUGH=='MANHATTAN'
ans
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-a1903c4320ab> in <module>()
#       8 mask = (df['DATE'] > '1/1/2016') & (df['DATE'] <= '12/31/2016')
#       9 #print(df.loc[mask])
# ---> 10 ans=(df.groupby(df['DATE'] > '1/1/2016') & (df['DATE'] <= '12/31/2016')).BOROUGH=='MANHATTAN'
#      11 ans
#      12
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
#     927                       is_integer_dtype(np.asarray(other)) else fill_bool)
#     928             return filler(self._constructor(
# --> 929                 na_op(self.values, other),
#     930                 index=self.index)).__finalize__(self)
#     931
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     875     def na_op(x, y):
#     876         try:
# --> 877             result = op(x, y)
#     878         except TypeError:
#     879             if isinstance(y, list):
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x, y)
#     123                  # For some reason ``^`` wasn't used in original.
#     124                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 125                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     126                                    names('rand_'), op('&')),
#     127                  ror_=bool_method(lambda x, y: operator.or_(y, x),
#
# ValueError: operands could not be broadcast together with shapes (2,2) (477732,)
