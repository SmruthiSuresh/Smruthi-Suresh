# %%
import pandas as pd
import csv
import datetime

dfa=pd.read_csv(r'C:\Users\smrut\Documents\Python\PythonAssignment3\Assignment 3\Data\employee_compensation.csv',sep=",")
aim=dfa[dfa.Year Type=='Calendar']
#dfa.head()
aim
# Out:
#   File "<ipython-input-44-80ddde54f3aa>", line 6
#     aim=dfa[dfa.Year Type=='Calendar']
#                         ^
# SyntaxError: invalid syntax

# %%
dfb=dfa.rename(columns = {'Total Compensation':'Total_Compensation','Total benefits':'Total_Benefits','Other Benefits' : 'Other_Benefits','Total Salary':'Total_Salary','Employee Identifier':'Employee_Identifier','Total Benefits':'Total_Benefits','Year Type':'Year_Type'})

dfb.head()
# Out:
#   Year_Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
# ...

# %%
dfb=dfb.loc[dfb.Year_Type=="Calendar"]
dfb.head()
# Out:
# Empty DataFrame
# Columns: [Year_Type, Year, Organization Group Code, Organization Group, Department Code, Department, Union Code, Union, Job Family Code, Job Family, Job Code, Job, Employee_Identifier, Salaries, Overtime, Other Salaries, Total_Salary, Retirement, Health/Dental, Other_Benefits, Total_Benefits, Total_Compensation, Mean Total_Compensation, Mean Total_Benefits, Mean Total_Salary, Mean Other_Benefits, PERCENT TOTAL BENEFITS]
# Index: []
#
# [0 rows x 27 columns]

# %%
dfb['Mean Total_Compensation']=pd.DataFrame(dfb.groupby('Employee_Identifier').Total_Compensation.mean())
dfb['Mean Total_Benefits']=pd.DataFrame(dfb.groupby('Employee_Identifier').Total_Benefits.mean())
dfb['Mean Total_Salary']=pd.DataFrame(dfb.groupby('Employee_Identifier').Total_Salary.mean())
dfb['Mean Other_Benefits']=pd.DataFrame(dfb.groupby('Employee_Identifier').Other_Benefits.mean())
dfb['Mean Total_Compensation']=pd.DataFrame(dfb.groupby('Employee_Identifier').Total_Compensation.mean())
dfb.head()
# Out:
# Empty DataFrame
# Columns: [Year_Type, Year, Organization Group Code, Organization Group, Department Code, Department, Union Code, Union, Job Family Code, Job Family, Job Code, Job, Employee_Identifier, Salaries, Overtime, Other Salaries, Total_Salary, Retirement, Health/Dental, Other_Benefits, Total_Benefits, Total_Compensation, Mean Total_Compensation, Mean Total_Benefits, Mean Total_Salary, Mean Other_Benefits, PERCENT TOTAL BENEFITS]
# Index: []
#
# [0 rows x 27 columns]

# %%
dfb['PERCENT TOTAL BENEFITS'] = (dfb['Total_Salary'] / dfb['Total_Compensation']) *100
dfb.head()
# Out:
#   Year_Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
# ...

# %%
dfb=dfb[dfb.Year_Type=='Calendar']
dfb.head()
# Out:
# Empty DataFrame
# Columns: [Year_Type, Year, Organization Group Code, Organization Group, Department Code, Department, Union Code, Union, Job Family Code, Job Family, Job Code, Job, Employee_Identifier, Salaries, Overtime, Other Salaries, Total_Salary, Retirement, Health/Dental, Other_Benefits, Total_Benefits, Total_Compensation, Mean Total_Compensation, Mean Total_Benefits, Mean Total_Salary, Mean Other_Benefits, PERCENT TOTAL BENEFITS]
# Index: []
#
# [0 rows x 27 columns]
