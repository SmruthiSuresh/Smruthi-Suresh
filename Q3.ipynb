# %%
import csv
import pandas as pd
from pandas import DataFrame
import numpy as np
import calendar

# %%
dfa=pd.read_csv(r'C:\Users\smrut\Documents\Python\PythonAssignment3\Assignment 3\Data\cricket_matches.csv',sep=",")
dfa.head()
# Out:
#                                        match_details  \
# 0  North Group:Durham v Nottinghamshire at Cheste...
# 1  South Group:Hampshire v Sussex at Southampton-...
# 2  Midlands/Wales/West Group:Somerset v Warwicksh...
# 3  South Group:Surrey v Middlesex at The Oval- Ju...
# 4  Midlands/Wales/West Group:Worcestershire v Nor...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# 1                            Hampshire won by 5 runs
# 2                        Warwickshire won by 19 runs
# 3   Surrey won by 4 wickets (with 4 balls remaining)
# 4  Worcestershire won by 1 wicket (with 2 balls r...
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# 2  Warwickshire 188/7 (20/20 ov); Somerset 169 (2...  13/06/2003
# ...

# %%
#Host and winner are same
dfa=dfa.loc[dfa['home'] == dfa['winner']]
dfa.head()
# Out:
#                                        match_details  \
# 0  North Group:Durham v Nottinghamshire at Cheste...
# 1  South Group:Hampshire v Sussex at Southampton-...
# 3  South Group:Surrey v Middlesex at The Oval- Ju...
# 4  Midlands/Wales/West Group:Worcestershire v Nor...
# 5  Midlands/Wales/West Group:Gloucestershire v Wo...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# 1                            Hampshire won by 5 runs
# 3   Surrey won by 4 wickets (with 4 balls remaining)
# 4  Worcestershire won by 1 wicket (with 2 balls r...
# 5  Gloucestershire won by 4 wickets (with 5 balls...
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# 3  Middlesex 155 (20/20 ov); Surrey 158/6 (19.2/2...  13/06/2003
# ...

# %%
if dfa.home in dfa.innings1:
    dfb=pd.DataFrame(dfa.groupby('home').innings1_runs.avg())
#elif dfa.home.equals(dfa.innings2):
 #   dfd=pd.DataFrame(dfa.groupby('winner').innings2_runs.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-e4b30c015c67> in <module>()
# ----> 1 if dfa.home in dfa.innings1:
#       2     dfb=pd.DataFrame(dfa.groupby('home').innings1_runs.avg())
#       3 #elif dfa.home.equals(dfa.innings2):
#       4  #   dfd=pd.DataFrame(dfa.groupby('winner').innings2_runs.mean())
#       5
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\core\generic.py in __contains__(self, key)
#     869     def __contains__(self, key):
#     870         """True if the key is in the info axis"""
# --> 871         return key in self._info_axis
#     872
#     873     @property
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\indexes\base.py in __contains__(self, key)
#    1391
#    1392     def __contains__(self, key):
# -> 1393         hash(key)
#    1394         # work around some kind of odd cython bug
#    1395         try:
#
# ...

# %%
dfb=dfb.rename(columns = {'innings2_runs':'Scores'})

# %%
dfb
# Out:
#                                            Scores
# home
# Abahani Limited                         95.000000
# Abbottabad Falcons                     120.363636
# Abbottabad Region                      155.000000
# Abbottabad Rhinos                      164.500000
# Adelaide Strikers                      149.555556
# Afghanistan                            124.804878
# Andhra                                 117.769231
# Antigua                                 98.000000
# Antigua Hawksbills                     106.000000
# Antigua and Barbuda                    129.000000
# Assam                                  127.812500
# Auckland                               147.942857
# Australia                              131.848485
# Australia A                            160.500000
# Azad Jammu & Kashmir Region             65.000000
# Badureliya Sports Club                 135.900000
# Bahawalpur Region                      143.600000
# Bahawalpur Stags                       139.333333
# ...
