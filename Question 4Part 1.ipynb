# %%
import csv
import pandas as pd

from pandas import DataFrame
import numpy as np

# %%
dfa=pd.read_csv('movies_awards.csv')
dfa = dfa.fillna(value=False)
dfa.head()
# Out:
#   totalSeasons                                               Plot  Rated  \
# 0         none                                              False  False
# 1         none                                              False  False
# 2         none                                              False  False
# 3         none  A historical classic drama in three acts; reto...  False
# 4         none  A father (Williams) suspects his son (Jackson)...      R
#
#   Response    Language                                              Title  \
# 0     True     English  Book of Love: The Definitive Reason Why Men Ar...
# 1     True     Swedish                              Anderssons älskarinna
# 2     True     English                                          Bad Blood
# 3     True  Portuguese                                       Who Are You?
# 4     True     English                            Skeletons in the Closet
#
#     Country                                Writer  Metascore  imdbRating  \
# ...

# %%
import re

# %%
dfa['Awards Won']= dfa['Awards'].str.extract('(\d) win', expand=True).rest_index()
dfa['Awards Nominated ']=dfa['Awards'].str.extract('(\d) nomination', expand=True).reset_index()
dfa['Prime_Awards_Nominated ']=dfa['Awards'].str.extract('Nominated for (\d) Primetime', expand=True).reset_index()
dfa['Oscar_Awards_Nominated ']=dfa['Awards'].str.extract('Nominated for (\d) Oscar', expand=True).reset_index
dfa['Oscar_Awards_Won ']=dfa['Awards'].str.extract('Won (\d) Oscar', expand=True).reset_index()
dfa['Prime_Awards_Won ']=dfa['Awards'].str.extract('Won (\d) Primetime', expand=True).reset_index()
dfa['BAFTA_Awards_Nominated ']=dfa['Awards'].str.extract('Nominated for (\d) BAFTA Film', expand=True).reset_index
dfa['Golden_Globe_Nominated ']=dfa['Awards'].str.extract('Nominated for (\d) Golden Globe', expand=True).reset_index
dfa['Golden_Globe_Nominated ']=dfa['Awards'].str.extract('Won (\d) Golden Globe', expand=True).reset_index()

#dfa['Total Awards Won or Nominated'] = dfa[['Awards Won','Awards Nominated']].sum(axis=1)


#dfa['Total Awards Won or Nominated'] = dfa.fillna(0)['Awards Won'] + dfa.fillna(0)['Awards Nominated']

#dfa['Awards Nominated ']=dfa['Awards'].str.extract('(\d) nominations.', expand=True)
#dfa['Awards Nominated ']=dfa['Awards'].str.extract('(\d) nominations.', expand=True)

dfa
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Awards Won'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-ddda5498dff2> in <module>()
#       1 import re
#       2
# ----> 3 dfa[['Won'," " , 'Nominated']] = (dfa.Awards.str.replace('&',' ').str.rpartition(' ', expand= True ))
#       4
#       5 #df.Awards= df.Awards.replace({'-': ' '}, regex=True)
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\core\strings.py in rpartition(self, pat, expand)
#    1477         f = lambda x: x.rpartition(pat)
#    1478         result = _na_map(f, self._data)
# -> 1479         return self._wrap_result(result, expand=expand)
#    1480
#    1481     @copy(str_get)
#
# C:\Users\smrut\Anaconda3\lib\site-packages\pandas\core\strings.py in _wrap_result(self, result, use_codes, name, expand)
#    1391             if expand:
#    1392                 cons = self._orig._constructor_expanddim
# ...

# %%
dfa.drop(dfa.columns[[29]], axis=1, inplace=True)

# %%
dfa.drop(dfa.columns[[21]], axis=1, inplace=True)
dfa
# Out:
#       totalSeasons                                               Plot  \
# 0             none                                              False
# 1             none                                              False
# 2             none                                              False
# 3             none  A historical classic drama in three acts; reto...
# 4             none  A father (Williams) suspects his son (Jackson)...
# 5             none  Four perky; clueless cheerleaders from the Hap...
# 6             none  Sandrine; a woman in her thirties gets tired o...
# 7             none  A rivalry develops between a showbiz veteran a...
# 8             none                 Three female friends behave badly.
# 9             none  An adaptation of Keith Laumer's short story; "...
# 10            none  A handful of human and alien survivors trapped...
# 11            none  At Pacific Palisades High; a poor Latino falls...
# ...
