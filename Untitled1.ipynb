# %%
import pandas as pd
import csv
import datetime
df4=pd.read_csv(r'C:\Users\smrut\Documents\Python\PythonAssignment3\Assignment 3\Data\employee_compensation.csv',sep=",")
df4.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
# ...

# %%
#df5=df4.groupby['Department'].Salaries.mean()

df5=df4.rename(columns = {'Total Compensation':'Total_Compensation','Organization Group':'Organization_Group'})

df5.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization_Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
# ...

# %%
df6=pd.DataFrame(df5.groupby('Department',sort=True).Total_Compensation.mean())
df6
# Out:
#                                         Total_Compensation
# Department
# Academy of Sciences                          107319.727692
# Adult Probation                              100179.758767
# Airport Commission                            96191.578234
# Arts Commission                               94339.597388
# Asian Art Museum                              71401.520060
# Assessor/Recorder                             89994.260614
# Board of Appeals                              51990.634889
# Board of Supervisors                          78801.347641
# Child Support Services                       100044.070997
# Children and Families Commission              96575.366190
# Children, Youth & Their Families              74304.933284
# City Attorney                                166082.677561
# City Planning                                 89022.876966
# Civil Service Commission                      67966.756559
# Community Investment & Infrastructure         42864.056538
# ...

# %%
df7['Organizaiton_Group']=pd.DataFrame(df5.groupby['Organization_Group'].Department
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-d08c830e3cd0> in <module>()
# ----> 1 df7['Organizaiton_Group']=pd.DataFrame(df5.groupby['Organization_Group'].Department.agg[('count')])
#
# TypeError: 'method' object is not subscriptable
